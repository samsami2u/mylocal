# %%
pwd
# Out:
# 'C:\\Users\\Administrator\\mylocal\\python'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\mylocal\\python'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Function Practice Exercises.ipynb',
#  '07-Statements Assessment Test.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  '10-Objects and Data Structures Assessment Test-Solution.ipynb',
#  'basic.ipynb',
#  'Blackjack Game.ipynb',
#  'CardGame.ipynb',
#  'ChapterNumbers.ipynb',
#  'Decorators.ipynb',
#  'ErrorHandling.ipynb',
#  'files modification.ipynb',
#  'FirstGame_TicTacToe - Copy.ipynb',
#  'FirstGame_TicTacToe.ipynb',
#  'Generators.ipynb',
#  'Kwargs.ipynb',
#  'lamba.ipynb',
#  'MethodsPractice.ipynb',
#  'ObjectOrientedProgramming Homework.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'Python Advance - collections.ipynb',
#  'Python advance - Files and Folders.ipynb',
#  'pythonFiles']

# %%
os.listdir('c:\\Users')
# Out:
# ['Administrator',
#  'All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'IT',
#  'Public']

# %%
import shutil

# %%
f = open('practicefile2.txt', 'w+')

# %%
f.write('This is a test file which will be used to move around.')
# Out:
# 54

# %%
f.close()

# %%
shutil.move('practicefile2.txt', 'c:\\Users\\IT')
# Out:
# 'c:\\Users\\IT\\practicefile2.txt'

# %%
os.listdir('c:\\users\\IT')
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.ms-ad',
#  '.ssh',
#  '.viminfo',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'mylocal',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'practicefile.txt',
#  'practicefile2.txt',
#  'PrintHood',
#  'Python Sachinh',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'sshkeygithub',
#  'sshkeygithub.pub',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\mylocal\\python'

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Function Practice Exercises.ipynb',
#  '07-Statements Assessment Test.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  '10-Objects and Data Structures Assessment Test-Solution.ipynb',
#  'basic.ipynb',
#  'Blackjack Game.ipynb',
#  'CardGame.ipynb',
#  'ChapterNumbers.ipynb',
#  'Decorators.ipynb',
#  'ErrorHandling.ipynb',
#  'files modification.ipynb',
#  'FirstGame_TicTacToe - Copy.ipynb',
#  'FirstGame_TicTacToe.ipynb',
#  'Generators.ipynb',
#  'Kwargs.ipynb',
#  'lamba.ipynb',
#  'MethodsPractice.ipynb',
#  'ObjectOrientedProgramming Homework.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'practicefile.txt',
#  'Python Advance - collections.ipynb',
#  'Python advance - Files and Folders.ipynb',
#  'pythonFiles']

# %%
shutil.move('c:\\Users\\IT\\practicefile2.txt', os.getcwd())
# Out:
# 'C:\\Users\\Administrator\\mylocal\\python\\practicefile2.txt'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\mylocal\\python'

# %%
os.dirlist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 os.dirlist()
#
# AttributeError: module 'os' has no attribute 'dirlist'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Function Practice Exercises.ipynb',
#  '07-Statements Assessment Test.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  '10-Objects and Data Structures Assessment Test-Solution.ipynb',
#  'basic.ipynb',
#  'Blackjack Game.ipynb',
#  'CardGame.ipynb',
#  'ChapterNumbers.ipynb',
#  'Decorators.ipynb',
#  'ErrorHandling.ipynb',
#  'files modification.ipynb',
#  'FirstGame_TicTacToe - Copy.ipynb',
#  'FirstGame_TicTacToe.ipynb',
#  'Generators.ipynb',
#  'Kwargs.ipynb',
#  'lamba.ipynb',
#  'MethodsPractice.ipynb',
#  'ObjectOrientedProgramming Homework.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'practicefile.txt',
#  'practicefile2.txt',
#  'Python Advance - collections.ipynb',
#  'Python advance - Files and Folders.ipynb',
#  'pythonFiles']

# %%
send2trash.send2trash('practicefile2.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Function Practice Exercises.ipynb',
#  '07-Statements Assessment Test.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  '10-Objects and Data Structures Assessment Test-Solution.ipynb',
#  'basic.ipynb',
#  'Blackjack Game.ipynb',
#  'CardGame.ipynb',
#  'ChapterNumbers.ipynb',
#  'Decorators.ipynb',
#  'ErrorHandling.ipynb',
#  'files modification.ipynb',
#  'FirstGame_TicTacToe - Copy.ipynb',
#  'FirstGame_TicTacToe.ipynb',
#  'Generators.ipynb',
#  'Kwargs.ipynb',
#  'lamba.ipynb',
#  'MethodsPractice.ipynb',
#  'ObjectOrientedProgramming Homework.ipynb',
#  'ObjectOrientedProgramming.ipynb',
#  'practicefile.txt',
#  'Python Advance - collections.ipynb',
#  'Python advance - Files and Folders.ipynb',
#  'pythonFiles']

# %%
for folders, sub_folders, files in os.walk('C:\\Users\\Administrator\\mylocal'):
    
    print(f"Currently looking at: {folders}")
    print('\n')
    print('The subfolders are:')
    
    for sub_fold in sub_folders:
        print('\n')
        print(f"Subfolder  : {sub_fold}")
        
    print('\n')
    print('The files are:')
    for f in files:
        print(f"\t file: {f}")
    print('\n')
# Out:
# Currently looking at: C:\Users\Administrator\mylocal
#
#
# The subfolders are:
#
#
# Subfolder  : .git
#
#
# Subfolder  : python
#
#
# The files are:
# 	 file: anothertst.txt
# 	 file: filefromupdate.txt
# 	 file: fkladsj
# 	 file: newtstfile.txt
# 	 file: README.md
# 	 file: tstfile.txt.txt
# 	 file: tstforstaging
#
#
# Currently looking at: C:\Users\Administrator\mylocal\.git
#
#
# The subfolders are:
#
#
# Subfolder  : hooks
#
#
# Subfolder  : info
#
#
# Subfolder  : logs
#
#
# Subfolder  : objects
#
#
# Subfolder  : refs
#
#
# The files are:
# 	 file: COMMIT_EDITMSG
# 	 file: config
# 	 file: description
# 	 file: FETCH_HEAD
# 	 file: HEAD
# 	 file: index
# 	 file: ORIG_HEAD
# 	 file: packed-refs
#
#
# Currently looking at: C:\Users\Administrator\mylocal\.git\hooks
#
#
# The subfolders are:
#
#
# The files are:
# 	 file: applypatch-msg.sample
# 	 file: commit-msg.sample
# 	 file: fsmonitor-watchman.sample
# 	 file: post-update.sample
# 	 file: pre-applypatch.sample
# ...
